# %%
#pip install -U seaborn

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Data

# %%
df = pd.read_csv('../data/cardio.csv', sep=';', index_col='id')
df.head()
# Out:
#       age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# id
# 0   18393       2     168    62.0    110     80            1     1      0
# 1   20228       1     156    85.0    140     90            3     1      0
# 2   18857       1     165    64.0    130     70            3     1      0
# 3   17623       2     169    82.0    150    100            1     1      0
# 4   17474       1     156    56.0    100     60            1     1      0
#
#     alco  active  cardio
# id
# 0      0       1       0
# 1      0       1       1
# 2      0       0       1
# 3      0       1       1
# 4      0       0       0

# %% [markdown]
# # Exploratory Data Analysis

# %%
# check null values
df.isnull().sum()
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
# check data types
df.dtypes
# Out:
# age              int64
# gender           int64
# height           int64
# weight         float64
# ap_hi            int64
# ap_lo            int64
# cholesterol      int64
# gluc             int64
# smoke            int64
# alco             int64
# active           int64
# cardio           int64
# dtype: object

# %%
df.describe()
# Out:
#                 age        gender        height        weight         ap_hi  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   19468.865814      1.349571    164.359229     74.205690    128.817286
# std     2467.251667      0.476838      8.210126     14.395757    154.011419
# min    10798.000000      1.000000     55.000000     10.000000   -150.000000
# 25%    17664.000000      1.000000    159.000000     65.000000    120.000000
# 50%    19703.000000      1.000000    165.000000     72.000000    120.000000
# 75%    21327.000000      2.000000    170.000000     82.000000    140.000000
# max    23713.000000      2.000000    250.000000    200.000000  16020.000000
#
#               ap_lo   cholesterol          gluc         smoke          alco  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      96.630414      1.366871      1.226457      0.088129      0.053771
# std      188.472530      0.680250      0.572270      0.283484      0.225568
# min      -70.000000      1.000000      1.000000      0.000000      0.000000
# 25%       80.000000      1.000000      1.000000      0.000000      0.000000
# 50%       80.000000      1.000000      1.000000      0.000000      0.000000
# 75%       90.000000      2.000000      1.000000      0.000000      0.000000
# max    11000.000000      3.000000      3.000000      1.000000      1.000000
#
#              active        cardio
# count  70000.000000  70000.000000
# mean       0.803729      0.499700
# std        0.397179      0.500003
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      0.000000
# 75%        1.000000      1.000000
# max        1.000000      1.000000

# %%
# lets adapt age in days to age in years
df.age = (df.age.values / 365).astype('int')

# %%
# show histograms 
for col in df.columns:
    plt.figure(figsize=(3,3))
    plt.hist(df[col])
    plt.title(col)
    plt.show()

# %%
# show boxplots stratified by target variable
for feat in df.columns:
    fig, axs = plt.subplots(1,1,figsize=(4,4))
    sns.boxplot(y=feat, x='cardio' , data=df, hue="cardio", orient='v', whis=0.9,  ax=axs)
    axs.set_title(feat)
    plt.show()

# %%
# show correlations
fig, axs = plt.subplots(1,1,figsize=(8,8))
corr_mat = df.corr()
sns.heatmap(corr_mat, annot=True, ax=axs)
plt.show()

# %% [markdown]
# # Modeling using Sklearn

# %%
df.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# id
# 0    50       2     168    62.0    110     80            1     1      0     0
# 1    55       1     156    85.0    140     90            3     1      0     0
# 2    51       1     165    64.0    130     70            3     1      0     0
# 3    48       2     169    82.0    150    100            1     1      0     0
# 4    47       1     156    56.0    100     60            1     1      0     0
#
#     active  cardio
# id
# 0        1       0
# 1        1       1
# 2        0       1
# 3        1       1
# 4        0       0

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
# seperate features and target
X = np.array(X).astype('float32')
y = np.array(y).astype('float32')

# %%
X.shape, y.shape
# Out:
# ((70000, 11), (70000,))

# %%
# train-test split
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
# min-max scale data for faster and more robust fitting
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[0.8571428 , 0.        , 0.7202797 , ..., 0.        , 0.        ,
#         1.        ],
#        [0.68571424, 0.        , 0.7342657 , ..., 0.        , 0.        ,
#         0.        ],
#        [0.6571429 , 0.        , 0.7342657 , ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [0.57142854, 1.        , 0.83216774, ..., 1.        , 0.        ,
#         1.        ],
#        [0.54285717, 1.        , 0.87412584, ..., 1.        , 0.        ,
#         0.        ],
#        [1.        , 1.        , 0.8881118 , ..., 1.        , 0.        ,
#         0.        ]], dtype=float32)

# %%
# first use sklearn models to later on benchmark aws models against
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, recall_score, precision_score, accuracy_score, f1_score

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# validate model´s performance

# train data
print('accuracy score on train data: {:.2f}'.format(accuracy_score(y_train, model.predict(X_train_scaled))))
print('rocauc score on train data: {:.2f}'.format(roc_auc_score(y_train, model.predict(X_train_scaled))))
print('recall score on train data: {:.2f}'.format(recall_score(y_train, model.predict(X_train_scaled))))
print('precision score on train data: {:.2f}'.format(precision_score(y_train, model.predict(X_train_scaled))))
print('f1 score on train data: {:.2f}'.format(f1_score(y_train, model.predict(X_train_scaled))))
print('-----------------\n')
# test data
print('accuracy score on test data: {:.2f}'.format(accuracy_score(y_test, model.predict(X_test_scaled))))
print('rocauc score on test data: {:.2f}'.format(roc_auc_score(y_test, model.predict(X_test_scaled))))
print('recall score on test data: {:.2f}'.format(recall_score(y_test, model.predict(X_test_scaled))))
print('precision score on test data: {:.2f}'.format(precision_score(y_test, model.predict(X_test_scaled))))
print('f1 score on test data: {:.2f}'.format(f1_score(y_test, model.predict(X_test_scaled))))
# Out:
# accuracy score on train data: 0.65
# rocauc score on train data: 0.65
# recall score on train data: 0.63
# precision score on train data: 0.66
# f1 score on train data: 0.64
# -----------------
#
# accuracy score on test data: 0.64
# rocauc score on test data: 0.64
# recall score on test data: 0.62
# precision score on test data: 0.64
# f1 score on test data: 0.63

# %% [markdown]
# # Modeling using Sagemaker

# %%
# Boto3 is the Amazon Web Services (AWS) Software Development Kit (SDK) for Python
# Boto3 allows Python developer to write software that makes use of services like Amazon S3 and Amazon EC2

import sagemaker
import boto3
from sagemaker import Session

# Let's create a Sagemaker session
#boto_session = boto3.Session(profile_name='ml_user_predict', region_name='us-east-1')
boto_session = boto3.Session()
sagemaker_session = sagemaker.Session(boto_session=boto_session)
#sagemaker_session = sagemaker.Session()

# %%
# create bucket if not exists
#s3 = boto3.resource('s3')
s3 = boto3.client('s3')
bucket = 'cardioprediction-ml-sagemaker'
s3.create_bucket(Bucket=bucket)
# Out:
# {'ResponseMetadata': {'RequestId': 'CG8X6P2TQZMW63NH',
#   'HostId': '2QNAEKUGGev/2LTXeF0zi0AZbiSw/L13NhCN14y4mJs7lRd4EAVXq0Q5disR0VSkqmTqk28nR2g=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '2QNAEKUGGev/2LTXeF0zi0AZbiSw/L13NhCN14y4mJs7lRd4EAVXq0Q5disR0VSkqmTqk28nR2g=',
#    'x-amz-request-id': 'CG8X6P2TQZMW63NH',
#    'date': 'Tue, 22 Nov 2022 15:11:23 GMT',
#    'location': '/cardioprediction-ml-sagemaker',
#    'server': 'AmazonS3',
#    'content-length': '0'},
#   'RetryAttempts': 0},
#  'Location': '/cardioprediction-ml-sagemaker'}

# %%
from sagemaker import get_execution_role

# get execution role
role = get_execution_role()
print(role)
# Out:
# arn:aws:iam::103721820087:role/service-role/AmazonSageMaker-ExecutionRole-20190909T202771

# %%
import io
import sagemaker.amazon.common as smac

# %%
# create in-memory byte array
buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, X_train_scaled, y_train)
buf.seek(0) # reset the buffer
# Out:
# 0

# %%
# upload data to s3
prefix = 'linear_learner'
key = 'linear-train-data'
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buf)

# let´s print the training data location in s3
s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)
print('uploaded training data to location: {}'.format(s3_train_data))

# let´s create an output placeholder in s3 to store the trained mode artifact
output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('Trained model artifact will be uploaded to: {}'.format(output_location))
# Out:
# uploaded training data to location: s3://cardioprediction-ml-sagemaker/linear_learner/train/linear-train-data
# Trained model artifact will be uploaded to: s3://cardioprediction-ml-sagemaker/linear_learner/output

# %%
# get reference to the linear learner container image
from sagemaker import image_uris
container = sagemaker.image_uris.retrieve(framework="linear-learner", 
                                          region=boto3.Session().region_name)

# %%
# instantiate the model
linear = sagemaker.estimator.Estimator(container,
                                      role, 
                                      instance_count=1,
                                      instance_type='ml.c4.xlarge',
                                      output_path=output_location,
                                      sagemaker_session=sagemaker_session,
                                      use_spot_instances=True,
                                      max_run=300,
                                      max_wait=600)

# %%
# set hyperparameter
linear.set_hyperparameters(feature_dim=X_train_scaled.shape[1], 
                           predictor_type='binary_classifier',
                           mini_batch_size=100,
                           epochs=5,
                           num_models=16,
                           loss='logistic')

# %%
# fit the model
linear.fit({'train': s3_train_data})
# Out:
# 2022-11-22 15:15:46 Starting - Starting the training job...
# 2022-11-22 15:16:13 Starting - Preparing the instances for trainingProfilerReport-1669130146: InProgress
# ......
# 2022-11-22 15:17:15 Downloading - Downloading input data...
# 2022-11-22 15:17:41 Training - Downloading the training image.........
# 2022-11-22 15:19:12 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [11/22/2022 15:19:15 INFO 139718335022912] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [11/22/2022 15:19:15 INFO 139718335022912] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'epochs': '5', 'feature_dim': '11', 'loss': 'logistic', 'mini_batch_size': '100', 'num_models': '16', 'predictor_type': 'binary_classifier'}
# [11/22/2022 15:19:15 INFO 139718335022912] Final configuration: {'mini_batch_size': '100', 'epochs': '5', 'feature_dim': '11', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': '16', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'logistic', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [11/22/2022 15:19:19 WARNING 139718335022912] Loggers have already been setup.
# [11/22/2022 15:19:19 INFO 139718335022912] Final configuration: {'mini_batch_size': '100', 'epochs': '5', 'feature_dim': '11', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': '16', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'logistic', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [11/22/2022 15:19:19 WARNING 139718335022912] Loggers have already been setup.
# Process 8 is a worker.
# [11/22/2022 15:19:19 INFO 139718335022912] Using default worker.
# [11/22/2022 15:19:19 INFO 139718335022912] Checkpoint loading and saving are disabled.
# [2022-11-22 15:19:19.388] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 15, "num_examples": 1, "num_bytes": 8800}
# [11/22/2022 15:19:19 INFO 139718335022912] Create Store: local
# [2022-11-22 15:19:19.790] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 401, "num_examples": 101, "num_bytes": 888800}
# [11/22/2022 15:19:19 INFO 139718335022912] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f122c721550>
# [11/22/2022 15:19:19 INFO 139718335022912] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [0.19189343 0.47541672 0.05757327 0.0758948  0.01593883 0.02070189
#  0.3406599  0.2829877  0.28773573 0.22961555 0.39805645]
# <NDArray 11 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [0.68099016 0.3451486  0.76439655 0.33722255 0.0177303  0.0150403
#  0.18425739 0.11143564 0.09108913 0.05584159 0.802574  ]
# <NDArray 11 @cpu(0)>}
# [11/22/2022 15:19:19 INFO 139718335022912] nvidia-smi: took 0.032 seconds to run.
# [11/22/2022 15:19:19 INFO 139718335022912] nvidia-smi identified 0 GPUs.
# [11/22/2022 15:19:19 INFO 139718335022912] Number of GPUs being used: 0
# #metrics {"StartTime": 1669130359.862874, "EndTime": 1669130359.862907, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 10200.0, "count": 1, "min": 10200, "max": 10200}, "Total Batches Seen": {"sum": 102.0, "count": 1, "min": 102, "max": 102}, "Max Records Seen Between Resets": {"sum": 10100.0, "count": 1, "min": 10100, "max": 10100}, "Max Batches Seen Between Resets": {"sum": 101.0, "count": 1, "min": 101, "max": 101}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2022-11-22 15:19:27.711] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 7848, "num_examples": 490, "num_bytes": 4312000}
# #metrics {"StartTime": 1669130367.7118702, "EndTime": 1669130367.7119358, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6303144143552196, "count": 1, "min": 0.6303144143552196, "max": 0.6303144143552196}}}
# #metrics {"StartTime": 1669130367.7120275, "EndTime": 1669130367.7120483, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.629669730439478, "count": 1, "min": 0.629669730439478, "max": 0.629669730439478}}}
# #metrics {"StartTime": 1669130367.712117, "EndTime": 1669130367.7121346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6319038932177485, "count": 1, "min": 0.6319038932177485, "max": 0.6319038932177485}}}
# #metrics {"StartTime": 1669130367.7121894, "EndTime": 1669130367.7122066, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6302116862705776, "count": 1, "min": 0.6302116862705776, "max": 0.6302116862705776}}}
# #metrics {"StartTime": 1669130367.7122724, "EndTime": 1669130367.712292, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.620112137463628, "count": 1, "min": 0.620112137463628, "max": 0.620112137463628}}}
# #metrics {"StartTime": 1669130367.712359, "EndTime": 1669130367.7123768, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6234890744734783, "count": 1, "min": 0.6234890744734783, "max": 0.6234890744734783}}}
# #metrics {"StartTime": 1669130367.7124338, "EndTime": 1669130367.712452, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6194563817394023, "count": 1, "min": 0.6194563817394023, "max": 0.6194563817394023}}}
# #metrics {"StartTime": 1669130367.7125049, "EndTime": 1669130367.7125223, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6235198651527872, "count": 1, "min": 0.6235198651527872, "max": 0.6235198651527872}}}
# #metrics {"StartTime": 1669130367.7125816, "EndTime": 1669130367.712594, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6326190493058185, "count": 1, "min": 0.6326190493058185, "max": 0.6326190493058185}}}
# #metrics {"StartTime": 1669130367.7126465, "EndTime": 1669130367.7126641, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6317173226804149, "count": 1, "min": 0.6317173226804149, "max": 0.6317173226804149}}}
# #metrics {"StartTime": 1669130367.7127314, "EndTime": 1669130367.7127504, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6317825416253537, "count": 1, "min": 0.6317825416253537, "max": 0.6317825416253537}}}
# #metrics {"StartTime": 1669130367.712821, "EndTime": 1669130367.7128377, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6315708961486817, "count": 1, "min": 0.6315708961486817, "max": 0.6315708961486817}}}
# #metrics {"StartTime": 1669130367.7128944, "EndTime": 1669130367.7129111, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6349417725387885, "count": 1, "min": 0.6349417725387885, "max": 0.6349417725387885}}}
# #metrics {"StartTime": 1669130367.7129588, "EndTime": 1669130367.712975, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6400701749373455, "count": 1, "min": 0.6400701749373455, "max": 0.6400701749373455}}}
# #metrics {"StartTime": 1669130367.7130258, "EndTime": 1669130367.7130427, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6350007683890206, "count": 1, "min": 0.6350007683890206, "max": 0.6350007683890206}}}
# #metrics {"StartTime": 1669130367.7130952, "EndTime": 1669130367.7131119, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6400558283280353, "count": 1, "min": 0.6400558283280353, "max": 0.6400558283280353}}}
# [11/22/2022 15:19:27 INFO 139718335022912] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.6303144143552196
# [11/22/2022 15:19:27 INFO 139718335022912] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.6194563817394023
# [11/22/2022 15:19:27 INFO 139718335022912] Epoch 0: Loss improved. Updating best model
# [11/22/2022 15:19:27 INFO 139718335022912] Saving model for epoch: 0
# [11/22/2022 15:19:27 INFO 139718335022912] Saved checkpoint to "/tmp/tmp42h1pehm/mx-mod-0000.params"
# [11/22/2022 15:19:27 INFO 139718335022912] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1669130359.8631606, "EndTime": 1669130367.7268083, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 59200.0, "count": 1, "min": 59200, "max": 59200}, "Total Batches Seen": {"sum": 592.0, "count": 1, "min": 592, "max": 592}, "Max Records Seen Between Resets": {"sum": 49000.0, "count": 1, "min": 49000, "max": 49000}, "Max Batches Seen Between Resets": {"sum": 490.0, "count": 1, "min": 490, "max": 490}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 49000.0, "count": 1, "min": 49000, "max": 49000}, "Number of Batches Since Last Reset": {"sum": 490.0, "count": 1, "min": 490, "max": 490}}}
# [11/22/2022 15:19:27 INFO 139718335022912] #throughput_metric: host=algo-1, train throughput=6231.097016350798 records/second
# [2022-11-22 15:19:35.930] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 8202, "num_examples": 490, "num_bytes": 4312000}
# #metrics {"StartTime": 1669130375.9301095, "EndTime": 1669130375.9301717, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.622843499242043, "count": 1, "min": 0.622843499242043, "max": 0.622843499242043}}}
# #metrics {"StartTime": 1669130375.930248, "EndTime": 1669130375.9302661, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6218641777817084, "count": 1, "min": 0.6218641777817084, "max": 0.6218641777817084}}}
# #metrics {"StartTime": 1669130375.9303215, "EndTime": 1669130375.9303439, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6230588336866729, "count": 1, "min": 0.6230588336866729, "max": 0.6230588336866729}}}
# #metrics {"StartTime": 1669130375.930396, "EndTime": 1669130375.930412, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6218365130521813, "count": 1, "min": 0.6218365130521813, "max": 0.6218365130521813}}}
# #metrics {"StartTime": 1669130375.9304652, "EndTime": 1669130375.9304852, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6002634228297642, "count": 1, "min": 0.6002634228297642, "max": 0.6002634228297642}}}
# #metrics {"StartTime": 1669130375.9305332, "EndTime": 1669130375.9305499, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6047606057147591, "count": 1, "min": 0.6047606057147591, "max": 0.6047606057147591}}}
# #metrics {"StartTime": 1669130375.9306004, "EndTime": 1669130375.9306226, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6001598540325555, "count": 1, "min": 0.6001598540325555, "max": 0.6001598540325555}}}
# #metrics {"StartTime": 1669130375.9306722, "EndTime": 1669130375.9306867, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6047452521032216, "count": 1, "min": 0.6047452521032216, "max": 0.6047452521032216}}}
# #metrics {"StartTime": 1669130375.9307275, "EndTime": 1669130375.9307468, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6243014074831593, "count": 1, "min": 0.6243014074831593, "max": 0.6243014074831593}}}
# #metrics {"StartTime": 1669130375.9307969, "EndTime": 1669130375.9308164, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6238656519675742, "count": 1, "min": 0.6238656519675742, "max": 0.6238656519675742}}}
# #metrics {"StartTime": 1669130375.9308667, "EndTime": 1669130375.930885, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6242522186746403, "count": 1, "min": 0.6242522186746403, "max": 0.6242522186746403}}}
# #metrics {"StartTime": 1669130375.9309456, "EndTime": 1669130375.9309616, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6238301627489985, "count": 1, "min": 0.6238301627489985, "max": 0.6238301627489985}}}
# #metrics {"StartTime": 1669130375.9310157, "EndTime": 1669130375.9310308, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6308793972560338, "count": 1, "min": 0.6308793972560338, "max": 0.6308793972560338}}}
# #metrics {"StartTime": 1669130375.9310691, "EndTime": 1669130375.9310846, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6390450198893645, "count": 1, "min": 0.6390450198893645, "max": 0.6390450198893645}}}
# #metrics {"StartTime": 1669130375.9311368, "EndTime": 1669130375.9311488, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6308742857952507, "count": 1, "min": 0.6308742857952507, "max": 0.6308742857952507}}}
# #metrics {"StartTime": 1669130375.93119, "EndTime": 1669130375.9312012, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6390428404516103, "count": 1, "min": 0.6390428404516103, "max": 0.6390428404516103}}}
# [11/22/2022 15:19:35 INFO 139718335022912] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.622843499242043
# [11/22/2022 15:19:35 INFO 139718335022912] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.6001598540325555
# [11/22/2022 15:19:35 INFO 139718335022912] Epoch 1: Loss improved. Updating best model
# [11/22/2022 15:19:35 INFO 139718335022912] Saving model for epoch: 1
# [11/22/2022 15:19:35 INFO 139718335022912] Saved checkpoint to "/tmp/tmp063iqa70/mx-mod-0000.params"
# [11/22/2022 15:19:35 INFO 139718335022912] #progress_metric: host=algo-1, completed 40.0 % of epochs
# #metrics {"StartTime": 1669130367.7273347, "EndTime": 1669130375.9385328, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 108200.0, "count": 1, "min": 108200, "max": 108200}, "Total Batches Seen": {"sum": 1082.0, "count": 1, "min": 1082, "max": 1082}, "Max Records Seen Between Resets": {"sum": 49000.0, "count": 1, "min": 49000, "max": 49000}, "Max Batches Seen Between Resets": {"sum": 490.0, "count": 1, "min": 490, "max": 490}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 49000.0, "count": 1, "min": 49000, "max": 49000}, "Number of Batches Since Last Reset": {"sum": 490.0, "count": 1, "min": 490, "max": 490}}}
# [11/22/2022 15:19:35 INFO 139718335022912] #throughput_metric: host=algo-1, train throughput=5967.372100932352 records/second
# [2022-11-22 15:19:43.832] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 7893, "num_examples": 490, "num_bytes": 4312000}
# #metrics {"StartTime": 1669130383.8323336, "EndTime": 1669130383.8323958, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.620909322621871, "count": 1, "min": 0.620909322621871, "max": 0.620909322621871}}}
# #metrics {"StartTime": 1669130383.8324876, "EndTime": 1669130383.8325083, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6182919103661362, "count": 1, "min": 0.6182919103661362, "max": 0.6182919103661362}}}
# #metrics {"StartTime": 1669130383.8325834, "EndTime": 1669130383.832603, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6210807932639608, "count": 1, "min": 0.6210807932639608, "max": 0.6210807932639608}}}
# #metrics {"StartTime": 1669130383.8326638, "EndTime": 1669130383.832682, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6182784128772969, "count": 1, "min": 0.6182784128772969, "max": 0.6182784128772969}}}
# #metrics {"StartTime": 1669130383.832739, "EndTime": 1669130383.832757, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5929504122831384, "count": 1, "min": 0.5929504122831384, "max": 0.5929504122831384}}}
# #metrics {"StartTime": 1669130383.8328123, "EndTime": 1669130383.8328292, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5995647178182797, "count": 1, "min": 0.5995647178182797, "max": 0.5995647178182797}}}
# #metrics {"StartTime": 1669130383.8328824, "EndTime": 1669130383.8328998, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5928614385955188, "count": 1, "min": 0.5928614385955188, "max": 0.5928614385955188}}}
# #metrics {"StartTime": 1669130383.8329659, "EndTime": 1669130383.832984, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.599560758084667, "count": 1, "min": 0.599560758084667, "max": 0.599560758084667}}}
# #metrics {"StartTime": 1669130383.8330386, "EndTime": 1669130383.8330555, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6231289376239387, "count": 1, "min": 0.6231289376239387, "max": 0.6231289376239387}}}
# #metrics {"StartTime": 1669130383.8331099, "EndTime": 1669130383.8331263, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6226217024666922, "count": 1, "min": 0.6226217024666922, "max": 0.6226217024666922}}}
# #metrics {"StartTime": 1669130383.8331883, "EndTime": 1669130383.8332162, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6230904669469717, "count": 1, "min": 0.6230904669469717, "max": 0.6230904669469717}}}
# #metrics {"StartTime": 1669130383.8332675, "EndTime": 1669130383.8332834, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.622607747603436, "count": 1, "min": 0.622607747603436, "max": 0.622607747603436}}}
# #metrics {"StartTime": 1669130383.8333356, "EndTime": 1669130383.8333511, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.627230684163619, "count": 1, "min": 0.627230684163619, "max": 0.627230684163619}}}
# #metrics {"StartTime": 1669130383.8334086, "EndTime": 1669130383.8334258, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6379588068748007, "count": 1, "min": 0.6379588068748007, "max": 0.6379588068748007}}}
# #metrics {"StartTime": 1669130383.8334768, "EndTime": 1669130383.8334928, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6272300349644252, "count": 1, "min": 0.6272300349644252, "max": 0.6272300349644252}}}
# #metrics {"StartTime": 1669130383.8335443, "EndTime": 1669130383.833561, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6379580365395059, "count": 1, "min": 0.6379580365395059, "max": 0.6379580365395059}}}
# [11/22/2022 15:19:43 INFO 139718335022912] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.620909322621871
# [11/22/2022 15:19:43 INFO 139718335022912] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.5928614385955188
# [11/22/2022 15:19:43 INFO 139718335022912] Epoch 2: Loss improved. Updating best model
# [11/22/2022 15:19:43 INFO 139718335022912] Saving model for epoch: 2
# [11/22/2022 15:19:43 INFO 139718335022912] Saved checkpoint to "/tmp/tmpg2vors_t/mx-mod-0000.params"
# [11/22/2022 15:19:43 INFO 139718335022912] #progress_metric: host=algo-1, completed 60.0 % of epochs
# #metrics {"StartTime": 1669130375.9389994, "EndTime": 1669130383.840494, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 157200.0, "count": 1, "min": 157200, "max": 157200}, "Total Batches Seen": {"sum": 1572.0, "count": 1, "min": 1572, "max": 1572}, "Max Records Seen Between Resets": {"sum": 49000.0, "count": 1, "min": 49000, "max": 49000}, "Max Batches Seen Between Resets": {"sum": 490.0, "count": 1, "min": 490, "max": 490}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 49000.0, "count": 1, "min": 49000, "max": 49000}, "Number of Batches Since Last Reset": {"sum": 490.0, "count": 1, "min": 490, "max": 490}}}
# [11/22/2022 15:19:43 INFO 139718335022912] #throughput_metric: host=algo-1, train throughput=6201.263993856696 records/second
# [2022-11-22 15:19:51.662] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 7821, "num_examples": 490, "num_bytes": 4312000}
# #metrics {"StartTime": 1669130391.6628938, "EndTime": 1669130391.6629462, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.619765213557652, "count": 1, "min": 0.619765213557652, "max": 0.619765213557652}}}
# #metrics {"StartTime": 1669130391.6630466, "EndTime": 1669130391.6630657, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6152560422469159, "count": 1, "min": 0.6152560422469159, "max": 0.6152560422469159}}}
# #metrics {"StartTime": 1669130391.6631346, "EndTime": 1669130391.6631525, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6199224547561334, "count": 1, "min": 0.6199224547561334, "max": 0.6199224547561334}}}
# #metrics {"StartTime": 1669130391.6632228, "EndTime": 1669130391.6632416, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.615245449144013, "count": 1, "min": 0.615245449144013, "max": 0.615245449144013}}}
# #metrics {"StartTime": 1669130391.6633022, "EndTime": 1669130391.6633186, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5889355443837692, "count": 1, "min": 0.5889355443837692, "max": 0.5889355443837692}}}
# #metrics {"StartTime": 1669130391.6633794, "EndTime": 1669130391.663402, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5975784178753288, "count": 1, "min": 0.5975784178753288, "max": 0.5975784178753288}}}
# #metrics {"StartTime": 1669130391.6634681, "EndTime": 1669130391.663486, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5888715936310437, "count": 1, "min": 0.5888715936310437, "max": 0.5888715936310437}}}
# #metrics {"StartTime": 1669130391.663542, "EndTime": 1669130391.6635594, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5975772594529756, "count": 1, "min": 0.5975772594529756, "max": 0.5975772594529756}}}
# #metrics {"StartTime": 1669130391.6636138, "EndTime": 1669130391.6636305, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.622532455210783, "count": 1, "min": 0.622532455210783, "max": 0.622532455210783}}}
# #metrics {"StartTime": 1669130391.6636832, "EndTime": 1669130391.6637003, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6219924538281499, "count": 1, "min": 0.6219924538281499, "max": 0.6219924538281499}}}
# #metrics {"StartTime": 1669130391.6637526, "EndTime": 1669130391.663769, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6224998402498206, "count": 1, "min": 0.6224998402498206, "max": 0.6224998402498206}}}
# #metrics {"StartTime": 1669130391.6638346, "EndTime": 1669130391.6638517, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6219856793929119, "count": 1, "min": 0.6219856793929119, "max": 0.6219856793929119}}}
# #metrics {"StartTime": 1669130391.663918, "EndTime": 1669130391.6639373, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6248027425493513, "count": 1, "min": 0.6248027425493513, "max": 0.6248027425493513}}}
# #metrics {"StartTime": 1669130391.6640027, "EndTime": 1669130391.6640208, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6370526445349869, "count": 1, "min": 0.6370526445349869, "max": 0.6370526445349869}}}
# #metrics {"StartTime": 1669130391.6640756, "EndTime": 1669130391.6640918, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.624802410982093, "count": 1, "min": 0.624802410982093, "max": 0.624802410982093}}}
# #metrics {"StartTime": 1669130391.6641574, "EndTime": 1669130391.6641762, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6370523777397311, "count": 1, "min": 0.6370523777397311, "max": 0.6370523777397311}}}
# [11/22/2022 15:19:51 INFO 139718335022912] #quality_metric: host=algo-1, epoch=3, train binary_classification_cross_entropy_objective <loss>=0.619765213557652
# [11/22/2022 15:19:51 INFO 139718335022912] #early_stopping_criteria_metric: host=algo-1, epoch=3, criteria=binary_classification_cross_entropy_objective, value=0.5888715936310437
# [11/22/2022 15:19:51 INFO 139718335022912] Epoch 3: Loss improved. Updating best model
# [11/22/2022 15:19:51 INFO 139718335022912] Saving model for epoch: 3
# [11/22/2022 15:19:51 INFO 139718335022912] Saved checkpoint to "/tmp/tmp_y7ug1zn/mx-mod-0000.params"
# [11/22/2022 15:19:51 INFO 139718335022912] #progress_metric: host=algo-1, completed 80.0 % of epochs
# #metrics {"StartTime": 1669130383.8409636, "EndTime": 1669130391.671242, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 206200.0, "count": 1, "min": 206200, "max": 206200}, "Total Batches Seen": {"sum": 2062.0, "count": 1, "min": 2062, "max": 2062}, "Max Records Seen Between Resets": {"sum": 49000.0, "count": 1, "min": 49000, "max": 49000}, "Max Batches Seen Between Resets": {"sum": 490.0, "count": 1, "min": 490, "max": 490}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 49000.0, "count": 1, "min": 49000, "max": 49000}, "Number of Batches Since Last Reset": {"sum": 490.0, "count": 1, "min": 490, "max": 490}}}
# [11/22/2022 15:19:51 INFO 139718335022912] #throughput_metric: host=algo-1, train throughput=6257.661499074249 records/second
# [2022-11-22 15:19:59.408] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 11, "duration": 7736, "num_examples": 490, "num_bytes": 4312000}
# #metrics {"StartTime": 1669130399.4080632, "EndTime": 1669130399.4083097, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6190697870059889, "count": 1, "min": 0.6190697870059889, "max": 0.6190697870059889}}}
# #metrics {"StartTime": 1669130399.4083824, "EndTime": 1669130399.4083958, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.612648589153679, "count": 1, "min": 0.612648589153679, "max": 0.612648589153679}}}
# #metrics {"StartTime": 1669130399.408454, "EndTime": 1669130399.4084733, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6192287389794174, "count": 1, "min": 0.6192287389794174, "max": 0.6192287389794174}}}
# #metrics {"StartTime": 1669130399.4085317, "EndTime": 1669130399.4085512, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6126408906274913, "count": 1, "min": 0.6126408906274913, "max": 0.6126408906274913}}}
# #metrics {"StartTime": 1669130399.4086103, "EndTime": 1669130399.4086275, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5866002191037548, "count": 1, "min": 0.5866002191037548, "max": 0.5866002191037548}}}
# #metrics {"StartTime": 1669130399.4086835, "EndTime": 1669130399.4087007, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5964756593509596, "count": 1, "min": 0.5964756593509596, "max": 0.5964756593509596}}}
# #metrics {"StartTime": 1669130399.4087567, "EndTime": 1669130399.4087734, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5865471800979303, "count": 1, "min": 0.5865471800979303, "max": 0.5865471800979303}}}
# #metrics {"StartTime": 1669130399.4088426, "EndTime": 1669130399.4088616, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.5964751567451322, "count": 1, "min": 0.5964751567451322, "max": 0.5964751567451322}}}
# #metrics {"StartTime": 1669130399.4089298, "EndTime": 1669130399.408957, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6221996724654217, "count": 1, "min": 0.6221996724654217, "max": 0.6221996724654217}}}
# #metrics {"StartTime": 1669130399.4090116, "EndTime": 1669130399.4090288, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.621650907555405, "count": 1, "min": 0.621650907555405, "max": 0.621650907555405}}}
# #metrics {"StartTime": 1669130399.4090824, "EndTime": 1669130399.4090993, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6221705425028898, "count": 1, "min": 0.6221705425028898, "max": 0.6221705425028898}}}
# #metrics {"StartTime": 1669130399.4091477, "EndTime": 1669130399.4091635, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6216472859285316, "count": 1, "min": 0.6216472859285316, "max": 0.6216472859285316}}}
# #metrics {"StartTime": 1669130399.409216, "EndTime": 1669130399.4092333, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6231330711987554, "count": 1, "min": 0.6231330711987554, "max": 0.6231330711987554}}}
# #metrics {"StartTime": 1669130399.4092844, "EndTime": 1669130399.4093013, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6362688080923898, "count": 1, "min": 0.6362688080923898, "max": 0.6362688080923898}}}
# #metrics {"StartTime": 1669130399.4093533, "EndTime": 1669130399.4093697, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6231329000044842, "count": 1, "min": 0.6231329000044842, "max": 0.6231329000044842}}}
# #metrics {"StartTime": 1669130399.409422, "EndTime": 1669130399.409438, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.6362686516898018, "count": 1, "min": 0.6362686516898018, "max": 0.6362686516898018}}}
# [11/22/2022 15:19:59 INFO 139718335022912] #quality_metric: host=algo-1, epoch=4, train binary_classification_cross_entropy_objective <loss>=0.6190697870059889
# [11/22/2022 15:19:59 INFO 139718335022912] #early_stopping_criteria_metric: host=algo-1, epoch=4, criteria=binary_classification_cross_entropy_objective, value=0.5865471800979303
# [11/22/2022 15:19:59 INFO 139718335022912] Epoch 4: Loss improved. Updating best model
# [11/22/2022 15:19:59 INFO 139718335022912] Saving model for epoch: 4
# [11/22/2022 15:19:59 INFO 139718335022912] Saved checkpoint to "/tmp/tmp5egjjb_p/mx-mod-0000.params"
# [11/22/2022 15:19:59 INFO 139718335022912] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1669130391.671722, "EndTime": 1669130399.4163518, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 255200.0, "count": 1, "min": 255200, "max": 255200}, "Total Batches Seen": {"sum": 2552.0, "count": 1, "min": 2552, "max": 2552}, "Max Records Seen Between Resets": {"sum": 49000.0, "count": 1, "min": 49000, "max": 49000}, "Max Batches Seen Between Resets": {"sum": 490.0, "count": 1, "min": 490, "max": 490}, "Reset Count": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Number of Records Since Last Reset": {"sum": 49000.0, "count": 1, "min": 49000, "max": 49000}, "Number of Batches Since Last Reset": {"sum": 490.0, "count": 1, "min": 490, "max": 490}}}
# [11/22/2022 15:19:59 INFO 139718335022912] #throughput_metric: host=algo-1, train throughput=6326.854882185315 records/second
# [11/22/2022 15:19:59 WARNING 139718335022912] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [11/22/2022 15:19:59 WARNING 139718335022912] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2022-11-22 15:19:59.418] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 13, "duration": 0, "num_examples": 1, "num_bytes": 8800}
# [2022-11-22 15:20:00.400] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 16, "duration": 980, "num_examples": 490, "num_bytes": 4312000}
# [2022-11-22 15:20:02.111] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 18, "duration": 1684, "num_examples": 490, "num_bytes": 4312000}
# [11/22/2022 15:20:02 INFO 139718335022912] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.5865136679824517)
# [11/22/2022 15:20:02 INFO 139718335022912] #train_score (algo-1) : ('binary_classification_accuracy', 0.7113673469387755)
# [11/22/2022 15:20:02 INFO 139718335022912] #train_score (algo-1) : ('binary_f_1.000', 0.7012021211416982)
# [11/22/2022 15:20:02 INFO 139718335022912] #train_score (algo-1) : ('precision', 0.7299639306765198)
# [11/22/2022 15:20:02 INFO 139718335022912] #train_score (algo-1) : ('recall', 0.6746209195495751)
# [11/22/2022 15:20:02 INFO 139718335022912] #train_score (algo-1) : ('roc_auc_score', 0.7756553739247312)
# [11/22/2022 15:20:02 INFO 139718335022912] #train_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [11/22/2022 15:20:02 INFO 139718335022912] #train_score (algo-1) : ('binary_log_loss', 0.6856390793225082)
# [11/22/2022 15:20:02 INFO 139718335022912] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.5865136679824517
# [11/22/2022 15:20:02 INFO 139718335022912] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.7113673469387755
# [11/22/2022 15:20:02 INFO 139718335022912] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.7012021211416982
# [11/22/2022 15:20:02 INFO 139718335022912] #quality_metric: host=algo-1, train precision <score>=0.7299639306765198
# [11/22/2022 15:20:02 INFO 139718335022912] #quality_metric: host=algo-1, train recall <score>=0.6746209195495751
# [11/22/2022 15:20:02 INFO 139718335022912] #quality_metric: host=algo-1, train roc_auc_score <score>=0.7756553739247312
# [11/22/2022 15:20:02 INFO 139718335022912] #quality_metric: host=algo-1, train binary_balanced_accuracy <score>=0.5
# [11/22/2022 15:20:02 INFO 139718335022912] #quality_metric: host=algo-1, train binary_log_loss <score>=0.6856390793225082
# [11/22/2022 15:20:02 INFO 139718335022912] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [11/22/2022 15:20:02 INFO 139718335022912] Saved checkpoint to "/tmp/tmpmyfgjqe6/mx-mod-0000.params"
# [11/22/2022 15:20:02 INFO 139718335022912] Test data is not provided.
# #metrics {"StartTime": 1669130359.371989, "EndTime": 1669130402.213267, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 489.2394542694092, "count": 1, "min": 489.2394542694092, "max": 489.2394542694092}, "epochs": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "check_early_stopping.time": {"sum": 4.663705825805664, "count": 5, "min": 0.8461475372314453, "max": 0.9961128234863281}, "update.time": {"sum": 39532.64927864075, "count": 5, "min": 7742.151975631714, "max": 8208.625078201294}, "finalize.time": {"sum": 2791.88871383667, "count": 1, "min": 2791.88871383667, "max": 2791.88871383667}, "setuptime": {"sum": 4.535913467407227, "count": 1, "min": 4.535913467407227, "max": 4.535913467407227}, "totaltime": {"sum": 43023.38004112244, "count": 1, "min": 43023.38004112244, "max": 43023.38004112244}}}
#
# 2022-11-22 15:20:18 Uploading - Uploading generated training model
# 2022-11-22 15:20:18 Completed - Training job completed
# Training seconds: 183
# Billable seconds: 85
# Managed Spot Training savings: 53.6%

# %% [markdown]
# # Deploy Model

# %%
# deploy model to perform inference
linear_classifier = linear.deploy(initial_instance_count=1,
                                  instance_type='ml.c4.xlarge')
# Out:
# --------!

# %%
from sagemaker.serializers import CSVSerializer
from sagemaker.deserializers import JSONDeserializer

linear_classifier.serializer = CSVSerializer()
linear_classifier.deserializer = JSONDeserializer()

# %% [markdown]
# # Model Evaluation

# %%
# predict on test data
predictions = linear_classifier.predict(X_test_scaled, initial_args={"ContentType": "text/csv"})
predictions['predictions'][:3]
# Out:
# [{'score': 0.5705273747444153, 'predicted_label': 1},
#  {'score': 0.8888561129570007, 'predicted_label': 1},
#  {'score': 0.3727778494358063, 'predicted_label': 0}]

# %%
# transform predictions
preds_score = np.array([pred['score'] for pred in predictions['predictions']])
preds_label = np.array([pred['predicted_label'] for pred in predictions['predictions']])

# %%
# validate model´s performance on test data
print('accuracy score on test data: {:.2f}'.format(accuracy_score(y_test, preds_label)))
print('rocauc score on test data: {:.2f}'.format(roc_auc_score(y_test, preds_score)))
print('recall score on test data: {:.2f}'.format(recall_score(y_test, preds_label)))
print('precision score on test data: {:.2f}'.format(precision_score(y_test, preds_label)))
print('f1 score on test data: {:.2f}'.format(f1_score(y_test, preds_label)))
# Out:
# accuracy score on test data: 0.71
# rocauc score on test data: 0.77
# recall score on test data: 0.68
# precision score on test data: 0.72
# f1 score on test data: 0.70

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, preds_label, normalize='true', labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0,1])
disp.plot()
plt.title('Confusion Matrix \n (normalized over true conditions)')
plt.xlabel('predicted label \n (0:healthy / 1: cardiovascular disease)')
plt.ylabel('true label')

plt.savefig('../figures/confusion_mat.png', format='png')

# %%
plt.show()

# %%
from sklearn.metrics import precision_recall_curve, PrecisionRecallDisplay

precision, recall, _ = precision_recall_curve(y_test, preds_score)

plt.figure(figsize=(6,4))
plt.plot(recall, precision)
plt.xlabel('recall')
plt.ylabel('precision')
plt.title('Recall-Precision Curve')
plt.grid('on')

plt.savefig('../figures/precision_recall.png', format='png')

# %%
plt.show()

# %% [markdown]
# # Improve the Model Using XGBoost

# %%
df.head()
# Out:
#     age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# id
# 0    50       2     168    62.0    110     80            1     1      0     0
# 1    55       1     156    85.0    140     90            3     1      0     0
# 2    51       1     165    64.0    130     70            3     1      0     0
# 3    48       2     169    82.0    150    100            1     1      0     0
# 4    47       1     156    56.0    100     60            1     1      0     0
#
#     active  cardio
# id
# 0        1       0
# 1        1       1
# 2        0       1
# 3        1       1
# 4        0       0

# %%
# put the target column first
cols = list(df.columns)
cols = [cols[-1]] + cols[:-1]
df = df[cols]
df.head()
# Out:
#     cardio  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# id
# 0        0   50       2     168    62.0    110     80            1     1
# 1        1   55       1     156    85.0    140     90            3     1
# 2        1   51       1     165    64.0    130     70            3     1
# 3        1   48       2     169    82.0    150    100            1     1
# 4        0   47       1     156    56.0    100     60            1     1
#
#     smoke  alco  active
# id
# 0       0     0       1
# 1       0     0       1
# 2       0     0       0
# 3       0     0       1
# 4       0     0       0

# %%
df_train, df_test = train_test_split(df, test_size=0.3)

# %%
# save to local
df_train.to_csv('../data/train.csv', header=False, index=False)
df_test.to_csv('../data/test.csv', header=False, index=False)

# %%
from sagemaker.xgboost.estimator import XGBoost

# %%
# upload data to s3
prefix = 'xgboost_learner'

# let´s print the training data location in s3
key = 'xgboost-train-data'
with open('../data/train.csv', 'rb') as f:
    boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(f)
s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)
print('uploaded training data to location: {}'.format(s3_train_data))

# let´s print the training data location in s3
key = 'xgboost-test-data'
with open('../data/test.csv', 'rb') as f:
    boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'test', key)).upload_fileobj(f)
s3_test_data = 's3://{}/{}/test/{}'.format(bucket, prefix, key)
print('uploaded test data to location: {}'.format(s3_test_data))

# let´s create an output placeholder in s3 to store the trained mode artifact
output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('Trained model artifact will be uploaded to: {}'.format(output_location))
# Out:
# uploaded training data to location: s3://cardioprediction-ml-sagemaker/xgboost_learner/train/xgboost-train-data
# uploaded test data to location: s3://cardioprediction-ml-sagemaker/xgboost_learner/test/xgboost-test-data
# Trained model artifact will be uploaded to: s3://cardioprediction-ml-sagemaker/xgboost_learner/output

# %%
container = sagemaker.image_uris.retrieve(framework="xgboost",
                                          version='0.90-2', 
                                          region=boto3.Session().region_name)

# %%
# instantiate the model
xgboost = sagemaker.estimator.Estimator(container,
                                          role, 
                                          instance_count=1,
                                          instance_type='ml.c4.xlarge',
                                          output_path=output_location,
                                          sagemaker_session=sagemaker_session,
                                          use_spot_instances=True,
                                          max_run=300,
                                          max_wait=600)

# %%
# set hyperparameters
xgboost.set_hyperparameters(max_depth=3,
                            objective='multi:softmax',
                            num_class=2,
                            eta=0.5,
                            num_round=100)

# %%
from sagemaker.inputs import TrainingInput
train_input = TrainingInput(s3_data=s3_train_data, content_type='csv', s3_data_type='S3Prefix')
valid_input = TrainingInput(s3_data=s3_test_data, content_type='csv', s3_data_type='S3Prefix')

# %%
#train_input = sagemaker.session.s3_input(s3_data=s3_train_data, content_type='csv', s3_data_type='S3Prefix')
#valid_input = sagemaker.session.s3_input(s3_data=s3_test_data, content_type='csv', s3_data_type='S3Prefix')

# %%
data_channels = {'train': train_input,
                 'validation': valid_input}

# %%
xgboost.fit(data_channels)
# Out:
# 2022-11-22 16:16:57 Starting - Starting the training job...
# 2022-11-22 16:17:26 Starting - Preparing the instances for trainingProfilerReport-1669133817: InProgress
# ............
# 2022-11-22 16:19:26 Downloading - Downloading input data...
# 2022-11-22 16:19:47 Training - Downloading the training image...
# 2022-11-22 16:20:28 Training - Training image download completed. Training in progress...INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value multi:softmax to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# [16:20:33] 49000x11 matrix with 539000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# INFO:root:Determined delimiter of CSV input is ','
# [16:20:33] 21000x11 matrix with 231000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# INFO:root:Single node training.
# [2022-11-22 16:20:33.278 ip-10-2-143-216.ec2.internal:8 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-11-22 16:20:33.278 ip-10-2-143-216.ec2.internal:8 INFO hook.py:151] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-11-22 16:20:33.278 ip-10-2-143-216.ec2.internal:8 INFO hook.py:196] Saving to /opt/ml/output/tensors
# INFO:root:Debug hook created from config
# INFO:root:Train matrix has 49000 rows
# INFO:root:Validation matrix has 21000 rows
# [0]#011train-merror:0.275041#011validation-merror:0.272286
# [2022-11-22 16:20:33.334 ip-10-2-143-216.ec2.internal:8 INFO hook.py:325] Monitoring the collections: metrics
# [1]#011train-merror:0.272571#011validation-merror:0.268333
# [2]#011train-merror:0.270449#011validation-merror:0.266714
# [3]#011train-merror:0.269061#011validation-merror:0.26519
# [4]#011train-merror:0.266755#011validation-merror:0.264048
# [5]#011train-merror:0.267531#011validation-merror:0.264714
# [6]#011train-merror:0.268061#011validation-merror:0.264381
# [7]#011train-merror:0.266082#011validation-merror:0.26319
# [8]#011train-merror:0.265735#011validation-merror:0.26281
# [9]#011train-merror:0.263653#011validation-merror:0.261333
# [10]#011train-merror:0.263245#011validation-merror:0.261524
# [11]#011train-merror:0.263755#011validation-merror:0.261476
# [12]#011train-merror:0.263469#011validation-merror:0.26081
# [13]#011train-merror:0.263347#011validation-merror:0.26081
# [14]#011train-merror:0.262816#011validation-merror:0.261571
# [15]#011train-merror:0.262776#011validation-merror:0.261476
# [16]#011train-merror:0.262918#011validation-merror:0.261286
# [17]#011train-merror:0.262673#011validation-merror:0.261714
# [18]#011train-merror:0.26202#011validation-merror:0.261857
# [19]#011train-merror:0.261816#011validation-merror:0.261762
# [20]#011train-merror:0.261673#011validation-merror:0.262143
# [21]#011train-merror:0.26149#011validation-merror:0.262619
# [22]#011train-merror:0.261408#011validation-merror:0.262429
# [23]#011train-merror:0.261469#011validation-merror:0.262286
# [24]#011train-merror:0.261245#011validation-merror:0.262619
# [25]#011train-merror:0.261347#011validation-merror:0.262667
# [26]#011train-merror:0.261224#011validation-merror:0.262667
# [27]#011train-merror:0.261143#011validation-merror:0.262857
# [28]#011train-merror:0.260878#011validation-merror:0.26319
# [29]#011train-merror:0.260878#011validation-merror:0.263143
# [30]#011train-merror:0.260612#011validation-merror:0.263238
# [31]#011train-merror:0.260592#011validation-merror:0.263143
# [32]#011train-merror:0.260571#011validation-merror:0.26319
# [33]#011train-merror:0.26049#011validation-merror:0.26319
# [34]#011train-merror:0.260408#011validation-merror:0.26319
# [35]#011train-merror:0.260367#011validation-merror:0.26319
# [36]#011train-merror:0.260755#011validation-merror:0.263
# [37]#011train-merror:0.260531#011validation-merror:0.263381
# [38]#011train-merror:0.260388#011validation-merror:0.26319
# [39]#011train-merror:0.26049#011validation-merror:0.262905
# [40]#011train-merror:0.260449#011validation-merror:0.262857
# [41]#011train-merror:0.260286#011validation-merror:0.262667
# [42]#011train-merror:0.260245#011validation-merror:0.262571
# [43]#011train-merror:0.260163#011validation-merror:0.262571
# [44]#011train-merror:0.260327#011validation-merror:0.262476
# [45]#011train-merror:0.260245#011validation-merror:0.262429
# [46]#011train-merror:0.260184#011validation-merror:0.262429
# [47]#011train-merror:0.260265#011validation-merror:0.262476
# [48]#011train-merror:0.260061#011validation-merror:0.263048
# [49]#011train-merror:0.259959#011validation-merror:0.262524
# [50]#011train-merror:0.259592#011validation-merror:0.262857
# [51]#011train-merror:0.259551#011validation-merror:0.262952
# [52]#011train-merror:0.259429#011validation-merror:0.26281
# [53]#011train-merror:0.259592#011validation-merror:0.26281
# [54]#011train-merror:0.259347#011validation-merror:0.262952
# [55]#011train-merror:0.259#011validation-merror:0.263333
# [56]#011train-merror:0.258816#011validation-merror:0.263286
# [57]#011train-merror:0.258816#011validation-merror:0.263333
# [58]#011train-merror:0.258735#011validation-merror:0.263143
# [59]#011train-merror:0.258714#011validation-merror:0.26319
# [60]#011train-merror:0.258612#011validation-merror:0.263333
# [61]#011train-merror:0.258551#011validation-merror:0.263143
# [62]#011train-merror:0.258388#011validation-merror:0.26319
# [63]#011train-merror:0.258286#011validation-merror:0.263286
# [64]#011train-merror:0.25802#011validation-merror:0.26319
# [65]#011train-merror:0.258286#011validation-merror:0.263333
# [66]#011train-merror:0.258224#011validation-merror:0.263238
# [67]#011train-merror:0.258041#011validation-merror:0.263333
# [68]#011train-merror:0.257857#011validation-merror:0.263429
# [69]#011train-merror:0.25798#011validation-merror:0.264095
# [70]#011train-merror:0.258061#011validation-merror:0.26419
# [71]#011train-merror:0.258#011validation-merror:0.264476
# [72]#011train-merror:0.258041#011validation-merror:0.264571
# [73]#011train-merror:0.257878#011validation-merror:0.264714
# [74]#011train-merror:0.257816#011validation-merror:0.265238
# [75]#011train-merror:0.257735#011validation-merror:0.26519
# [76]#011train-merror:0.257694#011validation-merror:0.265143
# [77]#011train-merror:0.257694#011validation-merror:0.26519
# [78]#011train-merror:0.257633#011validation-merror:0.265238
# [79]#011train-merror:0.257633#011validation-merror:0.265238
# [80]#011train-merror:0.257592#011validation-merror:0.265238
# [81]#011train-merror:0.257653#011validation-merror:0.265286
# [82]#011train-merror:0.257612#011validation-merror:0.265381
# [83]#011train-merror:0.257612#011validation-merror:0.265381
# [84]#011train-merror:0.25749#011validation-merror:0.265476
# [85]#011train-merror:0.257469#011validation-merror:0.265429
# [86]#011train-merror:0.257449#011validation-merror:0.265476
# [87]#011train-merror:0.257592#011validation-merror:0.265381
# [88]#011train-merror:0.257551#011validation-merror:0.265143
# [89]#011train-merror:0.257327#011validation-merror:0.265143
# [90]#011train-merror:0.257245#011validation-merror:0.264619
# [91]#011train-merror:0.257347#011validation-merror:0.264667
# [92]#011train-merror:0.257184#011validation-merror:0.264095
# [93]#011train-merror:0.25702#011validation-merror:0.264571
# [94]#011train-merror:0.256898#011validation-merror:0.264524
# [95]#011train-merror:0.256816#011validation-merror:0.264429
# [96]#011train-merror:0.256816#011validation-merror:0.264429
# [97]#011train-merror:0.256796#011validation-merror:0.264476
# [98]#011train-merror:0.256775#011validation-merror:0.264476
# [99]#011train-merror:0.256939#011validation-merror:0.264333
#
# 2022-11-22 16:20:54 Uploading - Uploading generated training model
# 2022-11-22 16:20:54 Completed - Training job completed
# Training seconds: 97
# Billable seconds: 38
# Managed Spot Training savings: 60.8%

# %% [markdown]
# # Deploy XGBOOST

# %%
# deploy model to perform inference
xgboost_classifier = xgboost.deploy(initial_instance_count=1,
                                      instance_type='ml.c4.xlarge')
# Out:
# ------!

# %%
#xgboost_classifier.content_type = 'text/csv'
xgboost_classifier.serializer = CSVSerializer
xgboost_classifier.deserializer = None

# %%
df_test.drop('cardio', axis=1)[0:1].values[0]
# Out:
# array([ 60.,   2., 175., 116., 120.,  70.,   2.,   3.,   0.,   0.,   1.])

# %%
np.array(df_test.drop('cardio', axis=1))
# Out:
# array([[ 60.,   2., 175., ...,   0.,   0.,   1.],
#        [ 52.,   1., 168., ...,   0.,   0.,   1.],
#        [ 53.,   2., 173., ...,   0.,   0.,   1.],
#        ...,
#        [ 58.,   1., 168., ...,   0.,   0.,   1.],
#        [ 41.,   2., 176., ...,   0.,   0.,   1.],
#        [ 57.,   1., 155., ...,   0.,   0.,   1.]])

# %%
# predict on test data
xgboost_classifier.predict(np.array(df_test.drop('cardio', axis=1)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-d24a923509bb> in <module>
#       1 # predict on test data
# ----> 2 xgboost_classifier.predict(np.array(df_test.drop('cardio', axis=1)))
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/predictor.py in predict(self, data, initial_args, target_model, target_variant, inference_id)
#     157
#     158         request_args = self._create_request_args(
# --> 159             data, initial_args, target_model, target_variant, inference_id
#     160         )
#     161         response = self.sagemaker_session.sagemaker_runtime_client.invoke_endpoint(**request_args)
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/predictor.py in _create_request_args(self, data, initial_args, target_model, target_variant, inference_id)
#     186
#     187         if "Accept" not in args:
# --> 188             args["Accept"] = ", ".join(self.accept)
#     189
#     190         if target_model:
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/predictor.py in accept(self)
#     543     def accept(self):
#     544         """The content type(s) that are expected from the inference endpoint."""
# --> 545         return self.deserializer.ACCEPT
#     546
#     547     @property
#
# AttributeError: 'NoneType' object has no attribute 'ACCEPT'

# %% [markdown]
# # Delete Model Endpoint

# %%
linear_classifier.delete_endpoint()
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-473-9aeeea792dd2> in <module>
# ----> 1 linear_classifier.delete_endpoint()
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/predictor.py in delete_endpoint(self, delete_endpoint_config)
#     327         """
#     328         if delete_endpoint_config:
# --> 329             self._delete_endpoint_config()
#     330
#     331         self.sagemaker_session.delete_endpoint(self.endpoint_name)
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/predictor.py in _delete_endpoint_config(self)
#     312         """Delete the Amazon SageMaker endpoint configuration"""
#     313         current_endpoint_config_name = self._get_endpoint_config_name()
# --> 314         self.sagemaker_session.delete_endpoint_config(current_endpoint_config_name)
#     315
#     316     def delete_endpoint(self, delete_endpoint_config=True):
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/session.py in delete_endpoint_config(self, endpoint_config_name)
#    3112                 "existing endpoint name".format(endpoint_name)
#    3113             )
# -> 3114
#    3115         self.sagemaker_client.update_endpoint(
#    3116             EndpointName=endpoint_name, EndpointConfigName=endpoint_config_name
#
# /opt/conda/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     413                     "%s() only accepts keyword arguments." % py_operation_name)
#     414             # The "self" in this scope is referring to the BaseClient.
# --> 415             return self._make_api_call(operation_name, kwargs)
#     416
#     417         _api_call.__name__ = str(py_operation_name)
#
# /opt/conda/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     743             error_code = parsed_response.get("Error", {}).get("Code")
#     744             error_class = self.exceptions.from_code(error_code)
# --> 745             raise error_class(parsed_response, operation_name)
#     746         else:
#     747             return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the DeleteEndpointConfig operation: Could not find endpoint configuration "arn:aws:sagemaker:us-east-1:103721820087:endpoint-config/linear-learner-2022-06-16-08-07-07-468".

# %%
xgboost_classifier.delete_endpoint()
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-472-6585d40f5450> in <module>
# ----> 1 xgboost_classifier.delete_endpoint()
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/predictor.py in delete_endpoint(self, delete_endpoint_config)
#     327         """
#     328         if delete_endpoint_config:
# --> 329             self._delete_endpoint_config()
#     330
#     331         self.sagemaker_session.delete_endpoint(self.endpoint_name)
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/predictor.py in _delete_endpoint_config(self)
#     312         """Delete the Amazon SageMaker endpoint configuration"""
#     313         current_endpoint_config_name = self._get_endpoint_config_name()
# --> 314         self.sagemaker_session.delete_endpoint_config(current_endpoint_config_name)
#     315
#     316     def delete_endpoint(self, delete_endpoint_config=True):
#
# /opt/conda/lib/python3.7/site-packages/sagemaker/session.py in delete_endpoint_config(self, endpoint_config_name)
#    3112                 "existing endpoint name".format(endpoint_name)
#    3113             )
# -> 3114
#    3115         self.sagemaker_client.update_endpoint(
#    3116             EndpointName=endpoint_name, EndpointConfigName=endpoint_config_name
#
# /opt/conda/lib/python3.7/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     413                     "%s() only accepts keyword arguments." % py_operation_name)
#     414             # The "self" in this scope is referring to the BaseClient.
# --> 415             return self._make_api_call(operation_name, kwargs)
#     416
#     417         _api_call.__name__ = str(py_operation_name)
#
# /opt/conda/lib/python3.7/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     743             error_code = parsed_response.get("Error", {}).get("Code")
#     744             error_class = self.exceptions.from_code(error_code)
# --> 745             raise error_class(parsed_response, operation_name)
#     746         else:
#     747             return parsed_response
#
# ClientError: An error occurred (ValidationException) when calling the DeleteEndpointConfig operation: Could not find endpoint configuration "arn:aws:sagemaker:us-east-1:103721820087:endpoint-config/sagemaker-xgboost-2022-06-15-18-28-51-226".
